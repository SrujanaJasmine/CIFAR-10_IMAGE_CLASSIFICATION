# %%
import copy
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Subset
import matplotlib.pyplot as plt

# %%
CIFAR_MEAN = (0.5, 0.5, 0.5)
CIFAR_STD  = (0.5, 0.5, 0.5)

def get_cifar10_loaders(batch_size=128, num_workers=2, val_size=5000, seed=SEED):
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(CIFAR_MEAN, CIFAR_STD),
    ])
    transform_eval = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(CIFAR_MEAN, CIFAR_STD),
    ])

    full_train_aug   = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=transform_train)
    full_train_noaug = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=transform_eval)
    testset = torchvision.datasets.CIFAR10(
        root='./data', train=False, download=True, transform=transform_eval)

    n = len(full_train_aug)
    indices = list(range(n))
    rng = np.random.RandomState(seed)
    rng.shuffle(indices)
    val_idx, train_idx = indices[:val_size], indices[val_size:]

    train_subset = Subset(full_train_aug, train_idx)
    val_subset   = Subset(full_train_noaug, val_idx)

    trainloader = DataLoader(train_subset, batch_size=batch_size,
                             shuffle=True, num_workers=num_workers,
                             pin_memory=True, drop_last=True)
    valloader   = DataLoader(val_subset,   batch_size=256,
                             shuffle=False, num_workers=num_workers,
                             pin_memory=True)
    testloader  = DataLoader(testset,      batch_size=256,
                             shuffle=False, num_workers=num_workers,
                             pin_memory=True)
    return trainloader, valloader, testloader

# %%
class IntermediateBlock(nn.Module):
    def __init__(self, in_channels, out_channels, num_branches=4):
        super().__init__()
        self.num_branches = num_branches
        self.branches = nn.ModuleList([
            nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=3,
                          padding=1, bias=False),
                nn.BatchNorm2d(out_channels),
                nn.ReLU(inplace=True),
            ) for _ in range(num_branches)
        ])
        self.weight_fc = nn.Linear(in_channels, num_branches)

    def forward(self, x):
        m = x.mean(dim=(2, 3))
        a = F.softmax(self.weight_fc(m), dim=1)
        branch_out = torch.stack([b(x) for b in self.branches], dim=1)
        a_view = a.view(a.size(0), a.size(1), 1, 1, 1)
        return (a_view * branch_out).sum(dim=1)


class CustomCNN(nn.Module):
    def __init__(self, num_classes=10, num_branches=4):
        super().__init__()
        self.b1 = IntermediateBlock(3,   128, num_branches)
        self.pool1 = nn.MaxPool2d(2)
        self.b2 = IntermediateBlock(128, 256, num_branches)
        self.pool2 = nn.MaxPool2d(2)
        self.b3 = IntermediateBlock(256, 256, num_branches)
        self.pool3 = nn.MaxPool2d(2)
        self.b4 = IntermediateBlock(256, 256, num_branches)

        self.classifier = nn.Sequential(
            nn.Linear(256, 128),
            nn.ReLU(inplace=True),
            nn.Dropout(0.4),
            nn.Linear(128, num_classes),
        )

    def forward(self, x):
        x = self.pool1(self.b1(x))
        x = self.pool2(self.b2(x))
        x = self.pool3(self.b3(x))
        x = self.b4(x)
        m = x.mean(dim=(2, 3))
        return self.classifier(m)

def init_weights(m):
    if isinstance(m, nn.Conv2d):
        nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
        if m.bias is not None:
            nn.init.zeros_(m.bias)
    elif isinstance(m, nn.Linear):
        nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
        if m.bias is not None:
            nn.init.zeros_(m.bias)
    elif isinstance(m, nn.BatchNorm2d):
        nn.init.ones_(m.weight)
        nn.init.zeros_(m.bias)

# %%
def train_one_epoch(model, loader, optimizer, loss_fn, device, batch_losses=None):
    model.train()
    running_loss = correct = total = 0
    for inputs, targets in loader:
        inputs  = inputs.to(device, non_blocking=True)
        targets = targets.to(device, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)
        outputs = model(inputs)
        loss = loss_fn(outputs, targets)
        loss.backward()
        optimizer.step()

        if batch_losses is not None:
            batch_losses.append(loss.item())

        running_loss += loss.item() * inputs.size(0)
        correct += outputs.max(1)[1].eq(targets).sum().item()
        total += targets.size(0)
    return running_loss / total, correct / total


@torch.no_grad()
def evaluate(model, loader, loss_fn, device):
    model.eval()
    running_loss = correct = total = 0
    for inputs, targets in loader:
        inputs  = inputs.to(device, non_blocking=True)
        targets = targets.to(device, non_blocking=True)
        outputs = model(inputs)
        loss = loss_fn(outputs, targets)
        running_loss += loss.item() * inputs.size(0)
        correct += outputs.max(1)[1].eq(targets).sum().item()
        total += targets.size(0)
    return running_loss / total, correct / total

# %%
def train_model(epochs=150, batch_size=128, lr=0.1, weight_decay=5e-4):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    trainloader, valloader, testloader = get_cifar10_loaders(batch_size=batch_size)

    model = CustomCNN().to(device)
    model.apply(init_weights)

    loss_fn = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=0.9,
                          weight_decay=weight_decay, nesterov=True)
    scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)

    history = {'train_loss': [], 'val_loss': [],
               'train_acc':  [], 'val_acc':  []}
    batch_losses = []
    best_val_acc = 0.0
    best_state   = None

    for epoch in range(epochs):
        train_loss, train_acc = train_one_epoch(
            model, trainloader, optimizer, loss_fn, device,
            batch_losses=batch_losses)
        val_loss, val_acc = evaluate(model, valloader, loss_fn, device)
        scheduler.step()

        history['train_loss'].append(train_loss)
        history['val_loss'].append(val_loss)
        history['train_acc'].append(train_acc * 100)
        history['val_acc'].append(val_acc * 100)


        if val_acc * 100 > best_val_acc:
            best_val_acc = val_acc * 100
            best_state = copy.deepcopy(model.state_dict())

        print(f"Epoch {epoch+1:3d}/{epochs}  "
              f"lr={optimizer.param_groups[0]['lr']:.4f}  "
              f"train_loss={train_loss:.4f}  "
              f"train_acc={train_acc*100:5.2f}%  val_acc={val_acc*100:5.2f}%  "
              f"(best_val={best_val_acc:.2f}%)")


    if best_state is not None:
        model.load_state_dict(best_state)
    test_loss, test_acc = evaluate(model, testloader, loss_fn, device)
    print(f"\nBest validation accuracy: {best_val_acc:.2f}%")
    print(f"Test accuracy of best-validation checkpoint: {test_acc*100:.2f}%")


    fig, axes = plt.subplots(1, 3, figsize=(18, 5))


    axes[0].plot(batch_losses, linewidth=0.5)
    axes[0].set_title("Training loss per batch")
    axes[0].set_xlabel("Batch"); axes[0].set_ylabel("Loss")


    axes[1].plot(history['train_acc'], label='Train')
    axes[1].plot(history['val_acc'],   label='Validation')
    axes[1].axhline(test_acc * 100, color='k', ls='--', lw=1,
                    label=f'Final test = {test_acc*100:.2f}%')
    axes[1].set_title("Accuracy per epoch")
    axes[1].set_xlabel("Epoch"); axes[1].set_ylabel("Accuracy (%)")
    axes[1].legend()


    axes[2].plot(history['train_loss'], label='Train')
    axes[2].plot(history['val_loss'],   label='Validation')
    axes[2].set_title("Loss per epoch")
    axes[2].set_xlabel("Epoch"); axes[2].set_ylabel("Loss")
    axes[2].legend()

    plt.tight_layout()
    plt.savefig("training_curves.png", dpi=120)
    plt.show()

    return model, history, batch_losses, best_val_acc, test_acc * 100

# %%
model, history, batch_losses, best_val_acc, test_acc = train_model(epochs=150)
print(f"\nFINAL TEST ACCURACY: {test_acc:.2f}%")
# Out:
# Using device: cuda
# Epoch   1/150  lr=0.1000  train_loss=1.5880  train_acc=40.66%  val_acc=54.42%  (best_val=54.42%)
# Epoch   2/150  lr=0.1000  train_loss=1.2043  train_acc=57.15%  val_acc=59.40%  (best_val=59.40%)
# Epoch   3/150  lr=0.0999  train_loss=1.0184  train_acc=64.16%  val_acc=65.10%  (best_val=65.10%)
# Epoch   4/150  lr=0.0998  train_loss=0.8997  train_acc=68.99%  val_acc=63.22%  (best_val=65.10%)
# Epoch   5/150  lr=0.0997  train_loss=0.8154  train_acc=72.52%  val_acc=68.08%  (best_val=68.08%)
# Epoch   6/150  lr=0.0996  train_loss=0.7528  train_acc=74.76%  val_acc=72.74%  (best_val=72.74%)
# Epoch   7/150  lr=0.0995  train_loss=0.7127  train_acc=75.91%  val_acc=69.38%  (best_val=72.74%)
# Epoch   8/150  lr=0.0993  train_loss=0.6773  train_acc=77.48%  val_acc=76.50%  (best_val=76.50%)
# Epoch   9/150  lr=0.0991  train_loss=0.6556  train_acc=77.92%  val_acc=76.10%  (best_val=76.50%)
# Epoch  10/150  lr=0.0989  train_loss=0.6351  train_acc=78.81%  val_acc=72.10%  (best_val=76.50%)
# Epoch  11/150  lr=0.0987  train_loss=0.6137  train_acc=79.40%  val_acc=75.76%  (best_val=76.50%)
# Epoch  12/150  lr=0.0984  train_loss=0.5988  train_acc=79.82%  val_acc=73.64%  (best_val=76.50%)
# Epoch  13/150  lr=0.0982  train_loss=0.5859  train_acc=80.48%  val_acc=76.94%  (best_val=76.94%)
# Epoch  14/150  lr=0.0979  train_loss=0.5723  train_acc=81.05%  val_acc=75.64%  (best_val=76.94%)
# Epoch  15/150  lr=0.0976  train_loss=0.5591  train_acc=81.53%  val_acc=77.40%  (best_val=77.40%)
# Epoch  16/150  lr=0.0972  train_loss=0.5568  train_acc=81.40%  val_acc=73.10%  (best_val=77.40%)
# Epoch  17/150  lr=0.0969  train_loss=0.5418  train_acc=81.89%  val_acc=80.64%  (best_val=80.64%)
# Epoch  18/150  lr=0.0965  train_loss=0.5361  train_acc=82.18%  val_acc=68.02%  (best_val=80.64%)
# Epoch  19/150  lr=0.0961  train_loss=0.5250  train_acc=82.49%  val_acc=79.38%  (best_val=80.64%)
# Epoch  20/150  lr=0.0957  train_loss=0.5133  train_acc=82.93%  val_acc=76.90%  (best_val=80.64%)
# Epoch  21/150  lr=0.0952  train_loss=0.5107  train_acc=82.84%  val_acc=80.14%  (best_val=80.64%)
# Epoch  22/150  lr=0.0948  train_loss=0.5057  train_acc=83.28%  val_acc=80.30%  (best_val=80.64%)
# Epoch  23/150  lr=0.0943  train_loss=0.4997  train_acc=83.32%  val_acc=72.44%  (best_val=80.64%)
# Epoch  24/150  lr=0.0938  train_loss=0.4967  train_acc=83.44%  val_acc=74.72%  (best_val=80.64%)
# Epoch  25/150  lr=0.0933  train_loss=0.4864  train_acc=83.84%  val_acc=76.64%  (best_val=80.64%)
# Epoch  26/150  lr=0.0928  train_loss=0.4834  train_acc=83.86%  val_acc=65.02%  (best_val=80.64%)
# Epoch  27/150  lr=0.0922  train_loss=0.4848  train_acc=83.88%  val_acc=75.08%  (best_val=80.64%)
# Epoch  28/150  lr=0.0916  train_loss=0.4752  train_acc=84.30%  val_acc=74.16%  (best_val=80.64%)
# Epoch  29/150  lr=0.0911  train_loss=0.4779  train_acc=83.86%  val_acc=73.36%  (best_val=80.64%)
# Epoch  30/150  lr=0.0905  train_loss=0.4637  train_acc=84.47%  val_acc=79.46%  (best_val=80.64%)
# Epoch  31/150  lr=0.0898  train_loss=0.4691  train_acc=84.31%  val_acc=80.16%  (best_val=80.64%)
# Epoch  32/150  lr=0.0892  train_loss=0.4649  train_acc=84.50%  val_acc=72.44%  (best_val=80.64%)
# Epoch  33/150  lr=0.0885  train_loss=0.4635  train_acc=84.78%  val_acc=78.36%  (best_val=80.64%)
# Epoch  34/150  lr=0.0878  train_loss=0.4602  train_acc=84.51%  val_acc=76.98%  (best_val=80.64%)
# Epoch  35/150  lr=0.0872  train_loss=0.4536  train_acc=84.74%  val_acc=74.04%  (best_val=80.64%)
# Epoch  36/150  lr=0.0864  train_loss=0.4480  train_acc=85.11%  val_acc=75.80%  (best_val=80.64%)
# Epoch  37/150  lr=0.0857  train_loss=0.4488  train_acc=85.02%  val_acc=78.54%  (best_val=80.64%)
# Epoch  38/150  lr=0.0850  train_loss=0.4384  train_acc=85.50%  val_acc=81.04%  (best_val=81.04%)
# Epoch  39/150  lr=0.0842  train_loss=0.4392  train_acc=85.50%  val_acc=80.68%  (best_val=81.04%)
# Epoch  40/150  lr=0.0835  train_loss=0.4381  train_acc=85.31%  val_acc=80.78%  (best_val=81.04%)
# Epoch  41/150  lr=0.0827  train_loss=0.4312  train_acc=85.71%  val_acc=72.36%  (best_val=81.04%)
# Epoch  42/150  lr=0.0819  train_loss=0.4331  train_acc=85.53%  val_acc=77.56%  (best_val=81.04%)
# Epoch  43/150  lr=0.0811  train_loss=0.4248  train_acc=85.90%  val_acc=82.32%  (best_val=82.32%)
# Epoch  44/150  lr=0.0802  train_loss=0.4247  train_acc=85.75%  val_acc=82.02%  (best_val=82.32%)
# Epoch  45/150  lr=0.0794  train_loss=0.4215  train_acc=85.99%  val_acc=76.60%  (best_val=82.32%)
# Epoch  46/150  lr=0.0785  train_loss=0.4170  train_acc=86.16%  val_acc=75.62%  (best_val=82.32%)
# Epoch  47/150  lr=0.0777  train_loss=0.4087  train_acc=86.22%  val_acc=74.84%  (best_val=82.32%)
# Epoch  48/150  lr=0.0768  train_loss=0.4127  train_acc=86.18%  val_acc=75.56%  (best_val=82.32%)
# Epoch  49/150  lr=0.0759  train_loss=0.4064  train_acc=86.54%  val_acc=79.84%  (best_val=82.32%)
# Epoch  50/150  lr=0.0750  train_loss=0.4080  train_acc=86.38%  val_acc=81.46%  (best_val=82.32%)
# Epoch  51/150  lr=0.0741  train_loss=0.3981  train_acc=86.80%  val_acc=76.82%  (best_val=82.32%)
# Epoch  52/150  lr=0.0732  train_loss=0.3987  train_acc=86.82%  val_acc=81.30%  (best_val=82.32%)
# Epoch  53/150  lr=0.0722  train_loss=0.3930  train_acc=86.82%  val_acc=82.06%  (best_val=82.32%)
# Epoch  54/150  lr=0.0713  train_loss=0.3955  train_acc=86.81%  val_acc=82.32%  (best_val=82.32%)
# Epoch  55/150  lr=0.0703  train_loss=0.3878  train_acc=87.04%  val_acc=82.12%  (best_val=82.32%)
# Epoch  56/150  lr=0.0694  train_loss=0.3823  train_acc=87.24%  val_acc=79.18%  (best_val=82.32%)
# Epoch  57/150  lr=0.0684  train_loss=0.3824  train_acc=87.06%  val_acc=80.90%  (best_val=82.32%)
# Epoch  58/150  lr=0.0674  train_loss=0.3767  train_acc=87.58%  val_acc=76.28%  (best_val=82.32%)
# Epoch  59/150  lr=0.0664  train_loss=0.3730  train_acc=87.57%  val_acc=84.42%  (best_val=84.42%)
# Epoch  60/150  lr=0.0655  train_loss=0.3699  train_acc=87.64%  val_acc=81.76%  (best_val=84.42%)
# Epoch  61/150  lr=0.0645  train_loss=0.3717  train_acc=87.67%  val_acc=80.56%  (best_val=84.42%)
# Epoch  62/150  lr=0.0634  train_loss=0.3641  train_acc=87.84%  val_acc=81.60%  (best_val=84.42%)
# Epoch  63/150  lr=0.0624  train_loss=0.3621  train_acc=87.96%  val_acc=79.46%  (best_val=84.42%)
# Epoch  64/150  lr=0.0614  train_loss=0.3576  train_acc=88.00%  val_acc=79.88%  (best_val=84.42%)
# Epoch  65/150  lr=0.0604  train_loss=0.3555  train_acc=88.05%  val_acc=84.52%  (best_val=84.52%)
# Epoch  66/150  lr=0.0594  train_loss=0.3488  train_acc=88.33%  val_acc=82.68%  (best_val=84.52%)
# Epoch  67/150  lr=0.0583  train_loss=0.3438  train_acc=88.32%  val_acc=82.76%  (best_val=84.52%)
# Epoch  68/150  lr=0.0573  train_loss=0.3425  train_acc=88.47%  val_acc=80.84%  (best_val=84.52%)
# Epoch  69/150  lr=0.0563  train_loss=0.3342  train_acc=88.98%  val_acc=83.14%  (best_val=84.52%)
# Epoch  70/150  lr=0.0552  train_loss=0.3365  train_acc=88.79%  val_acc=85.42%  (best_val=85.42%)
# Epoch  71/150  lr=0.0542  train_loss=0.3312  train_acc=89.00%  val_acc=80.92%  (best_val=85.42%)
# Epoch  72/150  lr=0.0531  train_loss=0.3310  train_acc=89.02%  val_acc=83.64%  (best_val=85.42%)
# Epoch  73/150  lr=0.0521  train_loss=0.3248  train_acc=89.19%  val_acc=83.14%  (best_val=85.42%)
# Epoch  74/150  lr=0.0510  train_loss=0.3165  train_acc=89.47%  val_acc=83.94%  (best_val=85.42%)
# Epoch  75/150  lr=0.0500  train_loss=0.3091  train_acc=89.77%  val_acc=82.74%  (best_val=85.42%)
# Epoch  76/150  lr=0.0490  train_loss=0.3069  train_acc=89.64%  val_acc=77.64%  (best_val=85.42%)
# Epoch  77/150  lr=0.0479  train_loss=0.3023  train_acc=89.95%  val_acc=78.44%  (best_val=85.42%)
# Epoch  78/150  lr=0.0469  train_loss=0.2977  train_acc=90.04%  val_acc=83.54%  (best_val=85.42%)
# Epoch  79/150  lr=0.0458  train_loss=0.2935  train_acc=90.12%  val_acc=80.40%  (best_val=85.42%)
# Epoch  80/150  lr=0.0448  train_loss=0.2848  train_acc=90.32%  val_acc=80.92%  (best_val=85.42%)
# Epoch  81/150  lr=0.0437  train_loss=0.2873  train_acc=90.38%  val_acc=83.64%  (best_val=85.42%)
# Epoch  82/150  lr=0.0427  train_loss=0.2816  train_acc=90.58%  val_acc=83.52%  (best_val=85.42%)
# Epoch  83/150  lr=0.0417  train_loss=0.2775  train_acc=90.76%  val_acc=82.66%  (best_val=85.42%)
# Epoch  84/150  lr=0.0406  train_loss=0.2708  train_acc=90.83%  val_acc=81.92%  (best_val=85.42%)
# Epoch  85/150  lr=0.0396  train_loss=0.2646  train_acc=91.11%  val_acc=85.02%  (best_val=85.42%)
# Epoch  86/150  lr=0.0386  train_loss=0.2592  train_acc=91.34%  val_acc=85.70%  (best_val=85.70%)
# Epoch  87/150  lr=0.0376  train_loss=0.2587  train_acc=91.30%  val_acc=84.52%  (best_val=85.70%)
# Epoch  88/150  lr=0.0366  train_loss=0.2515  train_acc=91.65%  val_acc=84.98%  (best_val=85.70%)
# Epoch  89/150  lr=0.0355  train_loss=0.2489  train_acc=91.79%  val_acc=82.54%  (best_val=85.70%)
# Epoch  90/150  lr=0.0345  train_loss=0.2431  train_acc=91.89%  val_acc=86.40%  (best_val=86.40%)
# Epoch  91/150  lr=0.0336  train_loss=0.2389  train_acc=91.99%  val_acc=83.10%  (best_val=86.40%)
# Epoch  92/150  lr=0.0326  train_loss=0.2305  train_acc=92.29%  val_acc=85.92%  (best_val=86.40%)
# Epoch  93/150  lr=0.0316  train_loss=0.2269  train_acc=92.35%  val_acc=85.72%  (best_val=86.40%)
# Epoch  94/150  lr=0.0306  train_loss=0.2189  train_acc=92.71%  val_acc=84.38%  (best_val=86.40%)
# Epoch  95/150  lr=0.0297  train_loss=0.2153  train_acc=92.78%  val_acc=87.00%  (best_val=87.00%)
# Epoch  96/150  lr=0.0287  train_loss=0.2113  train_acc=92.88%  val_acc=83.82%  (best_val=87.00%)
# Epoch  97/150  lr=0.0278  train_loss=0.2049  train_acc=93.20%  val_acc=86.94%  (best_val=87.00%)
# Epoch  98/150  lr=0.0268  train_loss=0.2024  train_acc=93.31%  val_acc=85.96%  (best_val=87.00%)
# Epoch  99/150  lr=0.0259  train_loss=0.1912  train_acc=93.64%  val_acc=87.56%  (best_val=87.56%)
# Epoch 100/150  lr=0.0250  train_loss=0.1894  train_acc=93.66%  val_acc=87.92%  (best_val=87.92%)
# Epoch 101/150  lr=0.0241  train_loss=0.1827  train_acc=93.91%  val_acc=86.02%  (best_val=87.92%)
# Epoch 102/150  lr=0.0232  train_loss=0.1757  train_acc=94.07%  val_acc=85.38%  (best_val=87.92%)
# Epoch 103/150  lr=0.0223  train_loss=0.1750  train_acc=94.28%  val_acc=85.56%  (best_val=87.92%)
# Epoch 104/150  lr=0.0215  train_loss=0.1671  train_acc=94.45%  val_acc=84.60%  (best_val=87.92%)
# Epoch 105/150  lr=0.0206  train_loss=0.1577  train_acc=94.73%  val_acc=87.84%  (best_val=87.92%)
# Epoch 106/150  lr=0.0198  train_loss=0.1531  train_acc=94.92%  val_acc=87.74%  (best_val=87.92%)
# Epoch 107/150  lr=0.0189  train_loss=0.1510  train_acc=95.03%  val_acc=85.74%  (best_val=87.92%)
# Epoch 108/150  lr=0.0181  train_loss=0.1376  train_acc=95.35%  val_acc=88.22%  (best_val=88.22%)
# Epoch 109/150  lr=0.0173  train_loss=0.1315  train_acc=95.79%  val_acc=86.82%  (best_val=88.22%)
# Epoch 110/150  lr=0.0165  train_loss=0.1284  train_acc=95.67%  val_acc=89.12%  (best_val=89.12%)
# Epoch 111/150  lr=0.0158  train_loss=0.1200  train_acc=96.11%  val_acc=87.10%  (best_val=89.12%)
# Epoch 112/150  lr=0.0150  train_loss=0.1145  train_acc=96.33%  val_acc=88.70%  (best_val=89.12%)
# Epoch 113/150  lr=0.0143  train_loss=0.1093  train_acc=96.49%  val_acc=88.40%  (best_val=89.12%)
# Epoch 114/150  lr=0.0136  train_loss=0.1048  train_acc=96.61%  val_acc=87.94%  (best_val=89.12%)
# Epoch 115/150  lr=0.0128  train_loss=0.1004  train_acc=96.71%  val_acc=89.82%  (best_val=89.82%)
# Epoch 116/150  lr=0.0122  train_loss=0.0910  train_acc=97.05%  val_acc=88.36%  (best_val=89.82%)
# Epoch 117/150  lr=0.0115  train_loss=0.0901  train_acc=97.03%  val_acc=88.08%  (best_val=89.82%)
# Epoch 118/150  lr=0.0108  train_loss=0.0774  train_acc=97.55%  val_acc=89.72%  (best_val=89.82%)
# Epoch 119/150  lr=0.0102  train_loss=0.0738  train_acc=97.70%  val_acc=88.60%  (best_val=89.82%)
# Epoch 120/150  lr=0.0095  train_loss=0.0674  train_acc=97.87%  val_acc=90.08%  (best_val=90.08%)
# Epoch 121/150  lr=0.0089  train_loss=0.0680  train_acc=97.86%  val_acc=88.34%  (best_val=90.08%)
# Epoch 122/150  lr=0.0084  train_loss=0.0568  train_acc=98.26%  val_acc=89.68%  (best_val=90.08%)
# Epoch 123/150  lr=0.0078  train_loss=0.0552  train_acc=98.33%  val_acc=89.56%  (best_val=90.08%)
# Epoch 124/150  lr=0.0072  train_loss=0.0486  train_acc=98.55%  val_acc=89.88%  (best_val=90.08%)
# Epoch 125/150  lr=0.0067  train_loss=0.0448  train_acc=98.64%  val_acc=89.88%  (best_val=90.08%)
# Epoch 126/150  lr=0.0062  train_loss=0.0420  train_acc=98.77%  val_acc=89.88%  (best_val=90.08%)
# Epoch 127/150  lr=0.0057  train_loss=0.0354  train_acc=99.03%  val_acc=90.52%  (best_val=90.52%)
# Epoch 128/150  lr=0.0052  train_loss=0.0305  train_acc=99.20%  val_acc=90.62%  (best_val=90.62%)
# Epoch 129/150  lr=0.0048  train_loss=0.0299  train_acc=99.25%  val_acc=91.22%  (best_val=91.22%)
# Epoch 130/150  lr=0.0043  train_loss=0.0255  train_acc=99.41%  val_acc=91.16%  (best_val=91.22%)
# Epoch 131/150  lr=0.0039  train_loss=0.0222  train_acc=99.47%  val_acc=91.08%  (best_val=91.22%)
# Epoch 132/150  lr=0.0035  train_loss=0.0230  train_acc=99.44%  val_acc=91.18%  (best_val=91.22%)
# Epoch 133/150  lr=0.0031  train_loss=0.0201  train_acc=99.56%  val_acc=91.54%  (best_val=91.54%)
# Epoch 134/150  lr=0.0028  train_loss=0.0176  train_acc=99.62%  val_acc=91.34%  (best_val=91.54%)
# Epoch 135/150  lr=0.0024  train_loss=0.0178  train_acc=99.58%  val_acc=91.42%  (best_val=91.54%)
# Epoch 136/150  lr=0.0021  train_loss=0.0159  train_acc=99.68%  val_acc=91.50%  (best_val=91.54%)
# Epoch 137/150  lr=0.0018  train_loss=0.0154  train_acc=99.70%  val_acc=91.38%  (best_val=91.54%)
# Epoch 138/150  lr=0.0016  train_loss=0.0139  train_acc=99.78%  val_acc=91.46%  (best_val=91.54%)
# Epoch 139/150  lr=0.0013  train_loss=0.0128  train_acc=99.79%  val_acc=91.68%  (best_val=91.68%)
# Epoch 140/150  lr=0.0011  train_loss=0.0131  train_acc=99.78%  val_acc=91.64%  (best_val=91.68%)
# Epoch 141/150  lr=0.0009  train_loss=0.0126  train_acc=99.77%  val_acc=91.62%  (best_val=91.68%)
# Epoch 142/150  lr=0.0007  train_loss=0.0116  train_acc=99.78%  val_acc=91.64%  (best_val=91.68%)
# Epoch 143/150  lr=0.0005  train_loss=0.0113  train_acc=99.82%  val_acc=91.94%  (best_val=91.94%)
# Epoch 144/150  lr=0.0004  train_loss=0.0114  train_acc=99.83%  val_acc=91.88%  (best_val=91.94%)
# Epoch 145/150  lr=0.0003  train_loss=0.0106  train_acc=99.84%  val_acc=91.92%  (best_val=91.94%)
# Epoch 146/150  lr=0.0002  train_loss=0.0115  train_acc=99.80%  val_acc=91.92%  (best_val=91.94%)
# Epoch 147/150  lr=0.0001  train_loss=0.0111  train_acc=99.82%  val_acc=91.78%  (best_val=91.94%)
# Epoch 148/150  lr=0.0000  train_loss=0.0114  train_acc=99.81%  val_acc=91.70%  (best_val=91.94%)
# Epoch 149/150  lr=0.0000  train_loss=0.0110  train_acc=99.82%  val_acc=91.64%  (best_val=91.94%)
# Epoch 150/150  lr=0.0000  train_loss=0.0110  train_acc=99.84%  val_acc=91.80%  (best_val=91.94%)
#
# Best validation accuracy: 91.94%
# Test accuracy of best-validation checkpoint: 91.69%
# FINAL TEST ACCURACY: 91.69%
